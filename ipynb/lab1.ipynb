# %% [markdown]
# inputqqq1q

# %%
#input 
a=input("Enter a number: ")
print("The given value is "+ a)

print(type(a)  )
# Out:
# The given value is 12
# <class 'str'>

# %%
a=int(input("Enter a number: "))
print("The given value is "+ str(a+11))
print("test:", a)
#print("test:"+ a)      #by '+' we can only concatenate str 
print(type(a) )
# Out:
# The given value is 23
# test: 12
# <class 'int'>

# %%
while True:
    a=input("Enter your birth year: ")
    if a.isdigit():
        print("you are "+ str(2026-int (a))+" years old")
        break
    print("wrong input")
# Out:
# wrong input
# you are 2014 years old

# %% [markdown]
# If Statement

# %%
x=int(input("Enter a integer: "))
if x<0:
    x=0
    print("Negative changed to zero")
elif x==0:
    print("Zero")
elif x==1:
    print("Single")
else :
    print("More")
# Out:
# Negative changed to zero

# %% [markdown]
# task

# %%
mark = int(input("Enter your mark: "))
if mark>100:
    print("Enter a valid task")
if mark >=90 and mark <=100:
    print("Grade A+")
if mark >=85 and mark <=89:
    print("Grade A")
if mark>=80 and mark <=84:

    print("Grade B+")
if mark>=70 and mark <=74:

    print("Grade B")
if mark<60:
    print("Grade F")
# Out:
# Grade A+

# %% [markdown]
# for loop

# %%
words =['cat','window','dhaka','jack']
for w in words:
    print (w, len (w))
# Out:
# cat 3
# window 6
# dhaka 5
# jack 4

# %%
#wards =['cat','window','dhaka','jack']
for i in range(0,len(words)):
    print(i,words[i],len(words[i]))
# Out:
# 0 cat 3
# 1 window 6
# 2 dhaka 5
# 3 jack 4

# %%
for i in range(5):
    print (i )
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list(range(5,10))
# Out:
# [5, 6, 7, 8, 9]

# %%
list(range(0,10,3))
# Out:
# [0, 3, 6, 9]

# %%
list (range(10,0,-2))
# Out:
# [10, 8, 6, 4, 2]

# %%
list(range(-10,-100,-30))
# Out:
# [-10, -40, -70]

# %%
for i in range(10,100,30):
    print (i)
# Out:
# 10
# 40
# 70

# %%
country ="bangladesh"
for i in country:
    print(i, end=" ")
# Out:
# b a n g l a d e s h

# %%
def operator(a,b):
    print (str(a)+" + "+str(b)+" = "+str(a+b))
    print (str(a)+" - "+str(b)+" = "+str(a-b))
    print (str(a)+" * ",b," = "+str(a*b))
    print (str(a)+" / ",b," = "+str(a/b))
operator (5,6)
# Out:
# 5 + 6 = 11
# 5 - 6 = -1
# 5 *  6  = 30
# 5 /  6  = 0.8333333333333334

# %%
def addnumbers(a,b):
    c=a+b
    return c

# %%
print (addnumbers(5.5,6))
# Out:
# 11.5

# %%
y= addnumbers("8ppp",'9')
print (y)
# Out:
# 8ppp9

# %%
addnumbers([22,33,44],[1,2,33])
a=[]
b=int(input("Enter a number: "))

addnumbers(a,[b])
# Out:
# [4]

# %%
def addvalues(num):
    sum=0
    for n in num:
        sum =sum+n
    return sum

# %%
v=[1,2,3,4,5]
addvalues(v)
# Out:
# 15

# %%
addvalues((9,7,6,4,3))
# Out:
# 29
